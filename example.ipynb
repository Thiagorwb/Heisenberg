# %%
import import_ipynb
from testing import *;
from Backends import *;

# %%
# just run once
jakarta = fetch_backend('ibmq_jakarta', simulated = False)
# Out:
# ibmqfactory.load_account:WARNING:2022-02-16 16:20:40,934: Credentials are already in use. The existing account in the session will be replaced.

# %%
# just run once
noisy_jakarta = fetch_backend('ibmq_jakarta', simulated = True)

# %%
jbasis = noisy_jakarta.configuration().basis_gates

# %%
sim = QasmSimulator()

# %%
qsd_qc(np.pi, backend = noisy_jakarta, coupling_map = line(3)).count_ops()
# Out:
# OrderedDict([('u', 92), ('cx', 42), ('u3', 8)])

# %%
t = np.pi/4
qr, qc = second_order_trotter(10, target_time = t, num_qubits = 7, operational_qubits = [3,5, 6], qsd = True, coupling_map = line(3))

qc.count_ops()
# Out:
# OrderedDict([('u1', 231), ('r', 168), ('cx', 63)])

# %%
t = np.pi
qr, qc = second_order_trotter(4, target_time = t, num_qubits = 3, qsd = True)
test(qc.to_instruction(),  target_time = t, backend = jakarta, verbose = True, shuttle = True)
# Out:
# Circuit Description
# OrderedDict([('rz', 525), ('sx', 240), ('cx', 54), ('x', 2)])
# global phase: 3π/4
#                                                                               »
# q210_0: ──────────────────────────────────────────────────────────────────────»
#                                                                               »
# q210_1: ──────────────────────────────────────────────────────────────────────»
#                                                                               »
# q210_2: ──────────────────────────────────────────────────────────────────────»
#         ┌─────────┐   ┌────┐  ┌─────────┐           ┌────┐          ┌────────┐»
# q210_3: ┤ Rz(0.0) ├───┤ √X ├──┤ Rz(π/2) ├───────────┤ √X ├──────────┤ Rz(3π) ├»
#         └─────────┘   └────┘  └─────────┘           └────┘          └────────┘»
# q210_4: ──────────────────────────────────────────────────────────────────────»
# ...

# %%
qr, qc = basic_trotter_circuit(ti_trotter, 6, num_qubits = 3, target_time = np.pi, compiler = True, qsd = True, coupling_map = line(3))
test(qc.to_instruction(),  target_time = np.pi, backend = jakarta, verbose = True, shuttle = True)
# Out:
# Circuit Description
# OrderedDict([('rz', 153), ('sx', 104), ('cx', 45), ('x', 2)])
# global phase: 2π
#                                                                       »
# q1014_0: ─────────────────────────────────────────────────────────────»
#                                                                       »
# q1014_1: ─────────────────────────────────────────────────────────────»
#                                                                       »
# q1014_2: ─────────────────────────────────────────────────────────────»
#          ┌────┐┌──────────┐               ┌────┐         ┌───────────┐»
# q1014_3: ┤ √X ├┤ Rz(-π/2) ├──■────────────┤ √X ├─────────┤ Rz(-5π/6) ├»
#          └────┘└──────────┘  │            └────┘         └───────────┘»
# q1014_4: ────────────────────┼────────────────────────────────────────»
#          ┌───┐    ┌────┐   ┌─┴─┐       ┌─────────┐                    »
# q1014_5: ┤ X ├────┤ √X ├───┤ X ├───────┤ Rz(π/3) ├────────────────────»
# ...

# %%
t = np.pi/8
test(qsd_qc(t, coupling_map = line(3)),  target_time = t, backend = noisy_jakarta, verbose = True, shuttle = True)
# Out:
# OrderedDict([('u', 104), ('cx', 51)])
# global phase: 5.1122
#                                                                               »
# q771_0: ──────────────────────────────────────────────────────────────────────»
#                                                                               »
# q771_1: ──────────────────────────────────────────────────────────────────────»
#                                                                               »
# q771_2: ──────────────────────────────────────────────────────────────────────»
#         ┌────────────────┐ ┌───────────────┐  ┌─────────────┐                 »
# q771_3: ┤ U(0,0,0.58452) ├─┤ U(1.5063,0,0) ├──┤ U(0,0,-π/2) ├─────────────────»
#         └────────────────┘ └───────────────┘  └─────────────┘                 »
# q771_4: ──────────────────────────────────────────────────────────────────────»
#           ┌───────────┐    ┌────────────────┐┌────────────────┐┌─────────────┐»
# ...

# %%
def kak2_gate(unitary):
    """
    Function decomposed two qubit unitary via KAK1 decomposition
    Input: 4 by 4 unitary matrix
    Output: Quantum Circuit Instructions for unitary using <= 3 CNOTs
    
    """
    
    dim, dim = np.shape(unitary)
    if dim == 2:
        return zyz_gate(unitary)
    
    # check if unitary and correct size
    if len(unitary) != 4 :
        print("Cannot decompose larger gates with ZYZ decomposition !")
    if not is_unitary(unitary):
        print("Matrix is not Unitary")
        
    kak1_decomposer = TwoQubitBasisDecomposer(CX, euler_basis = 'ZYZ')
    #return kak1_decomposer.decomp1(unitary)
    
    
    return kak1_decomposer(unitary).decompose()

# %%
u = U_12(t = np.pi/4)
qc = kak2_gate(u.to_matrix())

# %%
qc.draw()
# Out:
# global phase: 2.3575
#          ┌────────────┐  ┌─────────┐       ┌─────────┐    ┌────────────┐   »
# q35_0: ──┤ R(π/2,π/2) ├──┤ U1(π/2) ├───■───┤ U1(π/2) ├────┤ R(π/2,π/2) ├───»
#        ┌─┴────────────┴─┐├─────────┴┐┌─┴─┐┌┴─────────┴┐┌──┴────────────┴──┐»
# q35_1: ┤ R(-3.1403,π/2) ├┤ U1(-π/2) ├┤ X ├┤ U1(-3π/4) ├┤ R(0.0018714,π/2) ├»
#        └────────────────┘└──────────┘└───┘└───────────┘└──────────────────┘»
# «        ┌──────────┐     ┌──────────┐  ┌────────────┐                    »
# «q35_0: ─┤ U1(-π/2) ├──■──┤ U1(-π/2) ├──┤ R(π/2,π/2) ├─────────────────■──»
# «       ┌┴──────────┤┌─┴─┐└┬────────┬┘┌─┴────────────┴┐┌────────────┐┌─┴─┐»
# «q35_1: ┤ U1(-3π/4) ├┤ X ├─┤ U1(-π) ├─┤ R(1.5695,π/2) ├┤ U1(1.5695) ├┤ X ├»
# «       └───────────┘└───┘ └────────┘ └───────────────┘└────────────┘└───┘»
# «         ┌─────────┐   ┌─────────────┐
# «q35_0: ──┤ U1(π/2) ├───┤ R(-π/2,π/2) ├──
# «       ┌─┴─────────┴─┐┌┴─────────────┴─┐
# «q35_1: ┤ R(-π/2,π/2) ├┤ U1(-0.0013233) ├
# ...

# %%
m = Operator(ti_trotter(time = np.pi)).data;

# %%
gen_qsd(m).draw()
# Out:
# global phase: 4.3693
#         ┌────────────┐┌───────────────┐┌────────────┐       ┌─────────┐  »
# q70_0: ─┤ U1(1.7367) ├┤ R(2.2076,π/2) ├┤ U1(-2.207) ├──■────┤ U1(π/2) ├──»
#         ├────────────┤├───────────────┤├────────────┤┌─┴─┐┌─┴─────────┴─┐»
# q70_1: ─┤ U1(2.4361) ├┤ R(0.5528,π/2) ├┤ U1(1.1712) ├┤ X ├┤ U1(-3.1393) ├»
#        ┌┴────────────┤└───────────────┘└────────────┘└───┘└─────────────┘»
# q70_2: ┤ Rz(-1.0917) ├───────────────────────────────────────────────────»
#        └─────────────┘                                                   »
# «       ┌────────────────┐  ┌──────────┐      ┌──────────┐┌─────────────────┐»
# «q70_0: ┤ R(0.56993,π/2) ├──┤ U1(-π/2) ├───■──┤ U1(-π/2) ├┤ R(-0.36334,π/2) ├»
# «       ├────────────────┤┌─┴──────────┴┐┌─┴─┐└┬────────┬┘└┬───────────────┬┘»
# «q70_1: ┤ R(0.51483,π/2) ├┤ U1(-1.5735) ├┤ X ├─┤ U1(-π) ├──┤ R(1.5695,π/2) ├─»
# «       └────────────────┘└─────────────┘└───┘ └────────┘  └───────────────┘ »
# ...

# %%
gen_qsd(m).count_ops()
# Out:
# OrderedDict([('u1', 60), ('r', 32), ('cx', 24), ('rz', 8), ('ry', 4)])

# %%
transpile(ti_trotter(time = np.pi), basis_gates = jbasis).decompose().count_ops()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1050476fef9a> in <module>
# ----> 1 transpile(ti_trotter(time = np.pi), basis_gates = jbasis).decompose().count_ops()
#
# NameError: name 'jbasis' is not defined
